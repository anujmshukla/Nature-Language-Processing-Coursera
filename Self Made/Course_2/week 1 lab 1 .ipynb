# %%
import re 
from collections import Counter
import matplotlib.pyplot as plt

# %%
text = "I I I Am AM AM AM AM Am aM okkk okkk okkk what what what What ABout about you"
print(text)
print('string length : ',len(text))
# Out:
# I I I Am AM AM AM AM Am aM okkk okkk okkk what what what What ABout about you
# string length :  77

# %%
text = text.lower()
print(text)
print('string length : ',len(text))
# Out:
# i i i am am am am am am am okkk okkk okkk what what what what about about you
# string length :  77

# %%
text_split = text.split(" ")
print(text_split)
print('string length : ',len(text_split))
# Out:
# ['i', 'i', 'i', 'am', 'am', 'am', 'am', 'am', 'am', 'am', 'okkk', 'okkk', 'okkk', 'what', 'what', 'what', 'what', 'about', 'about', 'you']
# string length :  20

# %%
dict = Counter(text_split)
print(dict)
# Out:
# Counter({'am': 7, 'what': 4, 'i': 3, 'okkk': 3, 'about': 2, 'you': 1})

# %%
plt.bar(range(len(dict)), list(dict.values()), align='center', d)
# Out:
# <BarContainer object of 6 artists>
